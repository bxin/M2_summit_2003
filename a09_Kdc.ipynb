# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.jet()

# %%
aa = pd.read_csv('CtrlParameterFiles_2018-07-19_104314_surg/Kdc_Matrix_Params.csv', skiprows=8, header=None)
kdc = np.array(aa)[:,-1].reshape(aa[0][len(aa)-1],-1)

# %%
#fig, ax = plt.subplots(1,1, figsize=(15,15))
plt.imshow(kdc)
plt.colorbar();

# %%
kdc/50*2.23
# Out:
# array([[-0.96961765, -0.224499  , -0.15094977, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.23184857, -0.990679  , -0.17133639, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.18590428, -0.19741142, -0.92911698, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.27520465,
#         -0.00240166, -0.00354597],
#        [ 0.        ,  0.        ,  0.        , ..., -0.00215881,
#          0.27585415, -0.00263026],
#        [ 0.        ,  0.        ,  0.        , ..., -0.00301463,
#         -0.00228571,  0.2782886 ]])

# %%
plt.plot(kdc[:,0],'-o');
plt.grid()

# %%
#kdc[-1,0] = 1000
plt.plot(np.sum(kdc, axis=0),'-o');

# %%
aa = pd.read_csv('CtrlParameterFiles_2018-07-19_104314_surg/Hd_ax_Matrix_Params.csv', skiprows=8, header=None)
Hd_ax = np.array(aa)[:,-1].reshape(aa[0][len(aa)-1],-1)

# %%
Hd_ax
# Out:
# array([[ 0.66666632, -0.33333264,  0.66666632],
#        [ 0.77942008, -0.31876424,  0.53934416],
#        [ 0.87267716, -0.27569586,  0.4030187 ],
#        [ 0.94236356, -0.20601116,  0.26364759],
#        [ 0.98543095, -0.11275309,  0.12732214],
#        [ 0.98543111,  0.12732251, -0.11275362],
#        [ 0.9423632 ,  0.26364803, -0.20601123],
#        [ 0.87267755,  0.40301933, -0.27569688],
#        [ 0.77941994,  0.53934485, -0.31876479],
#        [ 0.66666632,  0.66666736, -0.33333368],
#        [ 0.53934418,  0.77942044, -0.31876463],
#        [ 0.40301873,  0.87267851, -0.27569724],
#        [ 0.26364762,  0.94236322, -0.20601084],
#        [ 0.12732216,  0.9854316 , -0.11275376],
#        [-0.11275376,  0.9854316 ,  0.12732216],
#        [-0.20601084,  0.94236322,  0.26364762],
#        [-0.27569724,  0.87267851,  0.40301873],
#        [-0.31876463,  0.77942044,  0.53934418],
#        [-0.33333368,  0.66666736,  0.66666632],
#        [-0.31876479,  0.53934485,  0.77941994],
# ...

# %%
aa = pd.read_csv('CtrlParameterFiles_2018-07-19_104314_surg/Hd_tan_Matrix_Params.csv', skiprows=8, header=None)
Hd_tan = np.array(aa)[:,-1].reshape(aa[0][len(aa)-1],-1)

# %%
Hd_tan
# Out:
# array([[ 0.66666667, -0.33333333,  0.66666667],
#        [ 0.66666667,  0.66666667, -0.33333333],
#        [-0.33333333,  0.66666667,  0.66666667]])
